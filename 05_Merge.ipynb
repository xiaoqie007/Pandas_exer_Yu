# %%
import pandas as pd
import numpy as np

# %%
cars1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")
cars2 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

# %%
cars1.head(1)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN

# %%
cars2.head(1)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
#
#    origin          car
# 0       3  honda civic

# %%
#ops it seems our first dataset has some unnamed blank columns, fix cars1
cars1 = cars1.loc[:, 'mpg':'car']
cars1.head(1)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu

# %%
# what is the number of observations in each dataset?
cars1.shape
# Out:
# (198, 9)

# %%
cars2.shape
# Out:
# (200, 9)

# %%
# join cars1 and cars2 into a single DataFrame called cars
cars = cars1.append(cars2)
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.shape
# Out:
# (398, 9)

# %%
#ops there is a column missing, called owners.Create a random number Series from 15000 to 73000
nr_owners = np.random.randint(15000, 73001, size = 398)
nr_owners
# Out:
# array([24905, 57305, 61469, 22837, 24953, 24097, 58256, 36136, 39413,
#        43869, 69336, 38860, 46706, 29850, 44466, 58696, 35272, 60258,
#        39392, 15091, 59870, 37068, 62399, 49744, 42737, 62718, 34765,
#        60503, 61855, 26035, 30931, 29184, 70305, 38673, 65977, 52766,
#        64578, 55060, 69097, 28852, 42650, 50374, 31311, 36564, 26365,
#        18914, 34463, 53725, 56119, 58848, 64135, 65859, 54760, 34738,
#        66516, 24216, 22148, 57574, 20825, 26335, 54194, 53870, 51759,
#        23781, 45529, 21099, 68505, 40083, 53825, 57905, 39172, 56085,
#        42794, 36419, 58816, 26684, 55229, 48763, 26494, 57912, 53889,
#        46268, 60652, 33507, 72445, 53066, 49851, 61532, 65153, 26297,
#        66877, 31939, 57988, 58519, 27076, 57294, 36330, 19365, 70255,
#        15298, 31429, 39939, 71405, 62907, 67868, 39214, 46322, 40958,
#        35956, 25595, 33544, 16557, 48108, 17606, 51460, 68147, 56697,
# ...

# %%
# Add the column owners to cars
cars['owners'] = nr_owners
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin              car  owners
# 195       1  ford mustang gl   53200
# 196       2        vw pickup   51335
# 197       1    dodge rampage   17637
# 198       1      ford ranger   56695
# 199       1       chevy s-10   56968

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 10 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null int64
# horsepower      398 non-null object
# weight          398 non-null int64
# acceleration    398 non-null float64
# model           398 non-null int64
# origin          398 non-null int64
# car             398 non-null object
# owners          398 non-null int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 34.2+ KB

# %%
#create the 3 DataFrames based on the followin raw data
raw_data_1 = {
    'subject_id': ['1', '2', '3', '4', '5'],
    'first_name': ['Alex', 'Amy', 'Ali', 'Aoni', 'Atiches'],
    'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
data1 = pd.DataFrame(raw_data_1)
data2 = pd.DataFrame(raw_data_2)
data3 = pd.DataFrame(raw_data_3)

# %%
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# **concat（）**

# %%
#join the two dataframes along rows and assign all_data
all_data = pd.concat([data1, data2])
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3        Ali       Ali
# 3          4       Aoni      Aoni
# 4          5    Atiches   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
#join the two dataframes along columns and assing to all_data_col
all_data_col = pd.concat([data1, data2], axis = 1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3        Ali       Ali          6       Bran   Balwner
# 3          4       Aoni      Aoni          7      Bryce     Brice
# 4          5    Atiches   Atiches          8      Betty    Btisan

# %%
#print data3
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# **merge**

# %%
#merge all_data and data3 along the subject_id value
pd.merge(all_data, data3, on = 'subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3        Ali       Ali       15
# 3          4       Aoni      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5    Atiches   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
# merge only the data that has the same 'subject_id' on both data1 and data2
pd.merge(data1, data2, on= 'subject_id', how = 'inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4         Aoni        Aoni        Billy      Bonder
# 1          5      Atiches     Atiches        Brian       Black

# %%
# merge all values in data1 and data2, with matching records from both side where available
pd.merge(data1, data2, on = 'subject_id', how = 'outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3          Ali         Ali          NaN         NaN
# 3          4         Aoni        Aoni        Billy      Bonder
# 4          5      Atiches     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - create 3 differents series, each of length 100,

# %%
s1 = pd.Series(np.random.randint(1, 5, 100))
s2 = pd.Series(np.random.randint(1, 4, 100))
s3 = pd.Series(np.random.randint(10000, 30001, 100))

# %%
#let's create a DataFrame by joinning the Series by column
housemkt = pd.concat([s1, s2,s3], axis = 1)
housemkt.head()
# Out:
#    0  1      2
# 0  4  1  13820
# 1  3  1  17279
# 2  2  3  25511
# 3  2  2  23700
# 4  2  1  13066

# %%
#change the name of the columns to bedrs, bathrs, price_sqr_meter ; rename方法和inplace方法
housemkt.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace = True)
housemkt.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      4       1            13820
# 1      3       1            17279
# 2      2       3            25511
# 3      2       2            23700
# 4      2       1            13066

# %%
#create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.concat([s1, s2, s3], axis = 0)

# it is still a Series, so we need to transfrom it to a DataFrame
bigcolumn = bigcolumn.to_frame()
bigcolumn.tail()
# Out:
#         0
# 95  22776
# 96  26107
# 97  10253
# 98  17381
# 99  25932

# %%
bigcolumn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 99
# Data columns (total 1 columns):
# 0    300 non-null int64
# dtypes: int64(1)
# memory usage: 4.7 KB

# %%
#ops it seem it is going only until index 99. is it true?
len(bigcolumn)
# Out:
# 300

# %%
#reindex the DataFrame so it foes from 0 to 299
bigcolumn.reset_index(drop= True, inplace=True) #源数据上直接替换

#bigcolumn.reset_index().tail()不会改变源数据

# %%
bigcolumn.tail()
# Out:
#          0
# 295  22776
# 296  26107
# 297  10253
# 298  17381
# 299  25932
