# %%
import pandas as pd
rul = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(rul, sep = '\t')

# %%
chipo.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
# 我们看一下item_price的数据类型
chipo.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#将item_price的类型转换为float
prices = [float(i[1:-1]) for i in chipo.item_price]
prices[:5]
# Out:
# [2.39, 3.39, 3.39, 2.39, 16.98]

# %%
chipo.item_price = prices
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo['item_price'] = prices

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo['item_price %'] = chipo['item_price'] / 100

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  item_price %
# 0                                                NaN        2.39        0.0239
# 1                                       [Clementine]        3.39        0.0339
# 2                                            [Apple]        3.39        0.0339
# 3                                                NaN        2.39        0.0239
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        0.1698

# %%
chipo_filtered = chipo.drop_duplicates(['item_name', 'quantity'])

# %%
chipo_filtered.count()
# Out:
# order_id              103
# quantity              103
# item_name             103
# choice_description     69
# item_price            103
# item_price %          103
# dtype: int64

# %%
chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# item_price %          4622
# dtype: int64

# %%
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
chipo_one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 21          11         1                       Barbacoa Burrito
# 27          14         1                       Carnitas Burrito
# ...

# %%
chipo_one_prod[chipo_one_prod.item_price >= 10].head(2)
# Out:
#    order_id  quantity      item_name  \
# 5         3         1   Chicken Bowl
# 7         4         1  Steak Burrito
#
#                                   choice_description  item_price  item_price %
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98        0.1098
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75        0.1175

# %%
chipo_one_prod[chipo_one_prod.item_price >= 10].item_name
# Out:
# 5                Chicken Bowl
# 7               Steak Burrito
# 39              Barbacoa Bowl
# 57             Veggie Burrito
# 62                Veggie Bowl
# 168     Barbacoa Crispy Tacos
# 186         Veggie Salad Bowl
# 250             Chicken Salad
# 606          Steak Salad Bowl
# 738         Veggie Soft Tacos
# 1132      Carnitas Salad Bowl
# 1229      Barbacoa Salad Bowl
# Name: item_name, dtype: object

# %%
chipo_one_prod[chipo_one_prod.item_price >= 10].order_id
# Out:
# 5         3
# 7         4
# 39       19
# 57       26
# 62       28
# 168      75
# 186      83
# 250     109
# 606     250
# 738     304
# 1132    468
# 1229    501
# Name: order_id, dtype: int64

# %%
chipo_reser_index = chipo_one_prod.reset_index()

# %%
chipo_reser_index.columns
# Out:
# Index(['index', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price', 'item_price %'],
#       dtype='object')

# %%
chipo_reser_index.head(1)
# Out:
#    index  order_id  quantity                     item_name choice_description  \
# 0      0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#    item_price  item_price %
# 0        2.39        0.0239

# %%
chipo_ok = chipo_reser_index[['quantity','item_name', 'item_price']]
chipo_ok
# Out:
#     quantity                              item_name  item_price
# 0          1           Chips and Fresh Tomato Salsa        2.39
# 1          1                                   Izze        3.39
# 2          1                       Nantucket Nectar        3.39
# 3          1  Chips and Tomatillo-Green Chili Salsa        2.39
# 4          1                           Chicken Bowl       10.98
# 5          1                          Side of Chips        1.69
# 6          1                          Steak Burrito       11.75
# 7          1                       Steak Soft Tacos        9.25
# 8          1                    Chips and Guacamole        4.45
# 9          1                   Chicken Crispy Tacos        8.75
# 10         1                     Chicken Soft Tacos        8.75
# 11         1                        Chicken Burrito        8.49
# 12         1                       Barbacoa Burrito        8.99
# 13         1                       Carnitas Burrito        8.99
# ...

# %%
del chipo_reser_index['order_id']

# %%
del chipo_reser_index['item_price %']

# %%
chipo_reser_index
# Out:
#     quantity                              item_name  \
# 0          1           Chips and Fresh Tomato Salsa
# 1          1                                   Izze
# 2          1                       Nantucket Nectar
# 3          1  Chips and Tomatillo-Green Chili Salsa
# 4          1                           Chicken Bowl
# 5          1                          Side of Chips
# 6          1                          Steak Burrito
# 7          1                       Steak Soft Tacos
# 8          1                    Chips and Guacamole
# 9          1                   Chicken Crispy Tacos
# 10         1                     Chicken Soft Tacos
# 11         1                        Chicken Burrito
# 12         1                       Barbacoa Burrito
# 13         1                       Carnitas Burrito
# 14         1                            Canned Soda
# 15         1                          Carnitas Bowl
# 16         1                          Bottled Water
# ...

# %%
chipo_ok.head(2)
# Out:
#    quantity                     item_name  item_price
# 0         1  Chips and Fresh Tomato Salsa        2.39
# 1         1                          Izze        3.39

# %%
chipo_ok.sort_values(by = 'item_price', ascending= False)
# Out:
#     quantity                              item_name  item_price
# 39         1                       Steak Salad Bowl       11.89
# 45         1                    Barbacoa Salad Bowl       11.89
# 44         1                    Carnitas Salad Bowl       11.89
# 6          1                          Steak Burrito       11.75
# 27         1                  Barbacoa Crispy Tacos       11.75
# 18         1                          Barbacoa Bowl       11.75
# 43         1                      Veggie Soft Tacos       11.25
# 28         1                      Veggie Salad Bowl       11.25
# 24         1                            Veggie Bowl       11.25
# 23         1                         Veggie Burrito       11.25
# 32         1                          Chicken Salad       10.98
# 4          1                           Chicken Bowl       10.98
# 7          1                       Steak Soft Tacos        9.25
# 38         1                  Carnitas Crispy Tacos        9.25
# ...

# %%
chipo.head(4)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description  item_price  item_price %
# 0                NaN        2.39        0.0239
# 1       [Clementine]        3.39        0.0339
# 2            [Apple]        3.39        0.0339
# 3                NaN        2.39        0.0239

# %%
chipo.loc[chipo.item_name.isin(['Izze', 'Nantucket Nectar']), ['item_price', 'item_price %']].head()
# Out:
#     item_price  item_price %
# 1         3.39        0.0339
# 2         3.39        0.0339
# 22        3.39        0.0339
# 24        3.39        0.0339
# 47        3.39        0.0339

# %%
chipo.loc[chipo.item_name.isin(['Chips and Fresh Tomato Salsa', 'Chips and Tomatillo-Green Chili Salsa']), 
         ['choice_description', 'item_price']].head(2)
# Out:
#   choice_description  item_price
# 0                NaN        2.39
# 3                NaN        2.39

# %%
pd.isnull(chipo).sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# item_price %             0
# dtype: int64

# %%
chipo.choice_description.fillna('orange', inplace= True)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  item_price %
# 0                                              apple        2.39        0.0239
# 1                                       [Clementine]        3.39        0.0339
# 2                                            [Apple]        3.39        0.0339
# 3                                              apple        2.39        0.0239
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        0.1698

# %%
import numpy as np

# %%
chipo.choice_description = np.nan

# %%
chipo.head(2)
# Out:
#    order_id  quantity                     item_name  choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                 NaN
# 1         1         1                          Izze                 NaN
#
#    item_price  item_price %
# 0        2.39        0.0239
# 1        3.39        0.0339

# %%
chipo.iloc[:20, 3] = 'apple'

# %%
chipo.iloc[19:22, 3]
# Out:
# 19    apple
# 20      NaN
# 21      NaN
# Name: choice_description, dtype: object

# %%
#统计NaN值数量
pd.isnull(chipo).sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    4602
# item_price               0
# item_price %             0
# dtype: int64

# %%
len(chipo)
# Out:
# 4622

# %%
chipo.choice_description.fillna('banana', inplace = True)

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#   choice_description  item_price  item_price %
# 0              apple        2.39        0.0239
# 1              apple        3.39        0.0339
# 2              apple        3.39        0.0339
# 3              apple        2.39        0.0239
# 4              apple       16.98        0.1698

# %%
import pandas as pd

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
data = pd.DataFrame(raw_data, columns= raw_data.keys())
data.head(1)
# Out:
#      regiment company    name  preTestScore  postTestScore
# 0  Nighthawks     1st  Miller             4             25

# %%
raw_data1 = {'序号': [1,2,3,4,5,6],
             '姓名': ['张三', '李四', '王五', '李六', '马七', '某某'], 
             '性别': ['男','男', '女', '男', '男', '女'],
             '年龄': ['12', '13', '12','15', '12', '15']
            }

# %%
data1 = pd.DataFrame(raw_data1, columns= raw_data1.keys())
data1
# Out:
#    序号  姓名 性别  年龄
# 0   1  张三  男  12
# 1   2  李四  男  13
# 2   3  王五  女  12
# 3   4  李六  男  15
# 4   5  马七  男  12
# 5   6  某某  女  15

# %%
data1.groupby('性别').describe()
# Out:
#       序号
#    count mean       std  min   25%  50%   75%  max
# 性别
# 女    2.0  4.5  2.121320  3.0  3.75  4.5  5.25  6.0
# 男    4.0  3.0  1.825742  1.0  1.75  3.0  4.25  5.0

# %%
data1['分数']= [86, 90, 76, 99, 100, 69]

# %%
data1
# Out:
#    序号  姓名 性别  年龄   分数
# 0   1  张三  男  12   86
# 1   2  李四  男  13   90
# 2   3  王五  女  12   76
# 3   4  李六  男  15   99
# 4   5  马七  男  12  100
# 5   6  某某  女  15   69

# %%
data1.describe()
# Out:
#              序号          分数
# count  6.000000    6.000000
# mean   3.500000   86.666667
# std    1.870829   12.388166
# min    1.000000   69.000000
# 25%    2.250000   78.500000
# 50%    3.500000   88.000000
# 75%    4.750000   96.750000
# max    6.000000  100.000000

# %%
data1.groupby(['年龄', '性别']).max().unstack()
# Out:
#      序号        姓名        分数
# 性别    女    男    女   男     女      男
# 年龄
# 12  3.0  5.0   王五  马七  76.0  100.0
# 13  NaN  2.0  NaN  李四   NaN   90.0
# 15  6.0  4.0   某某  李六  69.0   99.0

# %%
data1.groupby(['年龄', '性别']).max()
# Out:
#        序号  姓名   分数
# 年龄 性别
# 12 女    3  王五   76
#    男    5  马七  100
# 13 男    2  李四   90
# 15 女    6  某某   69
#    男    4  李六   99

# %%
data1.groupby(['年龄', '性别']).size()
# Out:
# 年龄  性别
# 12  女     1
#     男     2
# 13  男     1
# 15  女     1
#     男     1
# dtype: int64

# %%
for name, group in data1.groupby('性别'):
    print(name)
    print(group)
# Out:
# 女
#    序号  姓名 性别  年龄  分数
# 2   3  王五  女  12  76
# 5   6  某某  女  15  69
# 男
#    序号  姓名 性别  年龄   分数
# 0   1  张三  男  12   86
# 1   2  李四  男  13   90
# 3   4  李六  男  15   99
# 4   5  马七  男  12  100

# %%
train = pd.read_csv('train.csv')
train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
capitalizer = lambda x: x.capitalize()

# %%
train['Sex'].apply(capitalizer).head()
# Out:
# 0      Male
# 1    Female
# 2    Female
# 3    Female
# 4      Male
# Name: Sex, dtype: object

# %%
lowerr = lambda x: x.lower()

# %%
train['Sex'].apply(lowerr).head(2)
# Out:
# 0      male
# 1    female
# Name: Sex, dtype: object

# %%
upperr = lambda x: x.upper()

# %%
train['Sex'].apply(upperr).head()
# Out:
# 0      MALE
# 1    FEMALE
# 2    FEMALE
# 3    FEMALE
# 4      MALE
# Name: Sex, dtype: object

# %%
def majority(x):
    if x > 17:
        return True
    else:
        return False

# %%
train['Age_O'] = train['Age'].apply(majority)
train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age_O
# 0      0  A/5 21171   7.2500   NaN        S   True
# 1      0   PC 17599  71.2833   C85        C   True

# %%
train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train.Age_O.value_counts()
# Out:
# True     601
# False    290
# Name: Age_O, dtype: int64

# %%
train.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train.sort_values(by = 'Age', ascending= False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Age_O
# 630  male  80.0      0      0     27042  30.0000   A23        S   True
# 851  male  74.0      0      0    347060   7.7750   NaN        S   True
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C   True
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C   True
# 116  male  70.5      0      0    370369   7.7500   NaN        Q   True

# %%
def age(x):
    if x >= 60:
        return 3
    elif x <= 20:
        return 1
    else:
        return 2

# %%
train['Age_B'] = train.Age.apply(age)
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  Age_O  Age_B
# 0      0  A/5 21171  7.25   NaN        S   True      2

# %%
train.Age_B.value_counts()
# Out:
# 2    686
# 1    179
# 3     26
# Name: Age_B, dtype: int64

# %%
pd.isnull(train).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Age_O            0
# Age_B            0
# dtype: int64

# %%
train.Cabin.value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# E101           3
# F2             3
# D              3
# C22 C26        3
# E24            2
# C126           2
# E25            2
# B5             2
# C92            2
# B20            2
# B58 B60        2
# B22            2
# B28            2
# D36            2
# D35            2
# D20            2
# D17            2
# C125           2
# E121           2
# C2             2
# B18            2
# E8             2
# C123           2
# F4             2
# C78            2
# E44            2
#               ..
# A16            1
# E63            1
# B42            1
# C7             1
# E49            1
# B50            1
# B86            1
# C87            1
# D48            1
# A19            1
# C90            1
# B69            1
# D6             1
# B30            1
# C50            1
# B38            1
# B94            1
# C101           1
# D37            1
# C111           1
# C62 C64        1
# ...

# %%
train.Cabin.fillno = 0

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_O  Age_B
# 0      0         A/5 21171   7.2500   NaN        S   True      2
# 1      0          PC 17599  71.2833   C85        C   True      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S   True      2
# ...

# %%
import pandas as pd

# %%
apple = pd.read_csv('apple.csv')
apple.head(2)
# Out:
#          Date    Open    High     Low   Close      Volume  Ex-Dividend  \
# 0  2010-01-04  213.43  214.50  212.38  214.01  17633200.0          0.0
# 1  2010-01-05  214.60  215.59  213.25  214.38  21496600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  27.428730   27.56624  27.293790   27.503268  123432400.0
# 1          1.0  27.579091   27.70632  27.405597   27.550818  150476200.0

# %%
def times10(x):
    if type(x) in int64:
        return 10*x
    return x

# %%
apple.dtypes
# Out:
# Date            object
# Open             int64
# High           float64
# Low            float64
# Close          float64
# Volume         float64
# Ex-Dividend    float64
# Split Ratio    float64
# Adj. Open      float64
# Adj. High      float64
# Adj. Low       float64
# Adj. Close     float64
# Adj. Volume    float64
# dtype: object

# %%
apple['Open'] = apple['Open'].astype('int')

# %%
apple.dtypes
# Out:
# Date            object
# Open             int64
# High           float64
# Low            float64
# Close          float64
# Volume         float64
# Ex-Dividend    float64
# Split Ratio    float64
# Adj. Open      float64
# Adj. High      float64
# Adj. Low       float64
# Adj. Close     float64
# Adj. Volume    float64
# dtype: object

# %%
apple['Open'].head()
# Out:
# 0    213
# 1    214
# 2    214
# 3    211
# 4    210
# Name: Open, dtype: int64

# %%
apple['Open'].apply(times10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4e783ac65dd8> in <module>
# ----> 1 apple['Open'].apply(times10)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-34-8448bac7648f> in times10(x)
#       1 def times10(x):
# ----> 2     if type(x) in int64:
#       3         return 10*x
#       4     return x
#
# NameError: name 'int64' is not defined

# %%
#import the dataset from this address;Assign it to a variable called df
csv_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv'

# %%
df = pd.read_csv(csv_url)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
def times10(x):
    if type(x) in int:
        return 10*x
    return x

# %%
stud_alcoh = df.loc[:, 'school': 'guardian']
stud_alcoh.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %%
stud_alcoh.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %%
capitalizer = lambda x: x.capitalize()

# %%
stud_alcoh['Mjob'] = stud_alcoh['Mjob'].apply(capitalizer)
stud_alcoh['Fjob'] = stud_alcoh['Fjob'].apply(capitalizer)
stud_alcoh.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %%
def majority(x):
    if x > 17:
        return True
    else:
        return False

# %%
stud_alcoh['legal_drinker'] = stud_alcoh['age'].apply(majority)
stud_alcoh.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %%
def times10(x):
    if type(x) is int:
        return 10*x
    return x

# %%
stud_alcoh.apply(times10).head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %%
stud_alcoh.apply(times10).head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %%
stud_alcoh.dtypes
# Out:
# school           object
# sex              object
# age               int64
# address          object
# famsize          object
# Pstatus          object
# Medu              int64
# Fedu              int64
# Mjob             object
# Fjob             object
# reason           object
# guardian         object
# legal_drinker      bool
# dtype: object

# %%
stud_alcoh.applymap(times10).head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  180       U     GT3       A    40    40  At_home   Teacher
# 1     GP   F  170       U     GT3       T    10    10  At_home     Other
# 2     GP   F  150       U     LE3       T    10    10  At_home     Other
# 3     GP   F  150       U     GT3       T    40    20   Health  Services
# 4     GP   F  160       U     GT3       T    30    30    Other     Other
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %%
apple = pd.read_csv('apple.csv')
apple.head(2)
# Out:
#          Date    Open    High     Low   Close      Volume  Ex-Dividend  \
# 0  2010-01-04  213.43  214.50  212.38  214.01  17633200.0          0.0
# 1  2010-01-05  214.60  215.59  213.25  214.38  21496600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  27.428730   27.56624  27.293790   27.503268  123432400.0
# 1          1.0  27.579091   27.70632  27.405597   27.550818  150476200.0

# %%
apple.apply(times10).head(2)
# Out:
#          Date    Open    High     Low   Close      Volume  Ex-Dividend  \
# 0  2010-01-04  213.43  214.50  212.38  214.01  17633200.0          0.0
# 1  2010-01-05  214.60  215.59  213.25  214.38  21496600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  27.428730   27.56624  27.293790   27.503268  123432400.0
# 1          1.0  27.579091   27.70632  27.405597   27.550818  150476200.0

# %%
apple['Open'] = apple['Open'].astype('int')

# %%
apple.Open.dtype
# Out:
# dtype('int64')

# %%
apple.apply(times10).head(2)
# Out:
#          Date  Open    High     Low   Close      Volume  Ex-Dividend  \
# 0  2010-01-04   213  214.50  212.38  214.01  17633200.0          0.0
# 1  2010-01-05   214  215.59  213.25  214.38  21496600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  27.428730   27.56624  27.293790   27.503268  123432400.0
# 1          1.0  27.579091   27.70632  27.405597   27.550818  150476200.0

# %%
apple.dtypes
# Out:
# Date            object
# Open             int64
# High           float64
# Low            float64
# Close          float64
# Volume         float64
# Ex-Dividend    float64
# Split Ratio    float64
# Adj. Open      float64
# Adj. High      float64
# Adj. Low       float64
# Adj. Close     float64
# Adj. Volume    float64
# dtype: object

# %%
apple.applymap(times10).head(2)
# Out:
#          Date  Open    High     Low   Close      Volume  Ex-Dividend  \
# 0  2010-01-04  2130  214.50  212.38  214.01  17633200.0          0.0
# 1  2010-01-05  2140  215.59  213.25  214.38  21496600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  27.428730   27.56624  27.293790   27.503268  123432400.0
# 1          1.0  27.579091   27.70632  27.405597   27.550818  150476200.0

# %%
apple.applymap(times10).head(2)
# Out:
#          Date  Open    High     Low   Close      Volume  Ex-Dividend  \
# 0  2010-01-04  2130  214.50  212.38  214.01  17633200.0          0.0
# 1  2010-01-05  2140  215.59  213.25  214.38  21496600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  27.428730   27.56624  27.293790   27.503268  123432400.0
# 1          1.0  27.579091   27.70632  27.405597   27.550818  150476200.0

# %%
apple['Open'].map(times10).head()
# Out:
# 0    2130
# 1    2140
# 2    2140
# 3    2110
# 4    2100
# Name: Open, dtype: int64

# %%
apple['Open'].max()
# Out:
# 702

# %%
f = lambda x: x.max() - x.min()
